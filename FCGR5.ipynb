# %% [markdown]
# For the first step we will import every function needed in our code , we will work basically with Tensorflow Library where we will use it for a simple CNN , then for an Hybrid Model (CNN+RNN) , then for a pre-trained vgg16 model and finally for a ResNet50 pre-trained Model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, LSTM, Conv1D, Reshape, MaxPooling1D, TimeDistributed, Bidirectional
from keras.layers import Input
from keras.applications import VGG16, ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
img_height, img_width = 224, 224
batch_size = 32
data_dir = 'FCGR_Analysiss_k5'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'),
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(data_dir, 'validation'),
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(data_dir, 'test'),
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 2032 images belonging to 2 classes.
# Found 580 images belonging to 2 classes.
# Found 292 images belonging to 2 classes.

# %%
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

cnn_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 11,169,089
# Trainable params: 11,169,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_cnn_model.h5', save_best_only=True)
]

history_cnn = cnn_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 53s 824ms/step - loss: 0.7011 - accuracy: 0.5207 - val_loss: 0.6933 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 49s 768ms/step - loss: 0.6925 - accuracy: 0.5103 - val_loss: 0.6914 - val_accuracy: 0.5034 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 46s 713ms/step - loss: 0.6916 - accuracy: 0.5064 - val_loss: 0.6912 - val_accuracy: 0.5034 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 46s 724ms/step - loss: 0.6888 - accuracy: 0.5374 - val_loss: 0.6883 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 48s 757ms/step - loss: 0.6853 - accuracy: 0.5527 - val_loss: 0.6788 - val_accuracy: 0.6155 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 49s 770ms/step - loss: 0.6733 - accuracy: 0.6004 - val_loss: 0.6675 - val_accuracy: 0.6241 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 48s 746ms/step - loss: 0.6529 - accuracy: 0.6403 - val_loss: 0.6459 - val_accuracy: 0.6362 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 48s 744ms/step - loss: 0.6154 - accuracy: 0.6885 - val_loss: 0.6090 - val_accuracy: 0.7603 - lr: 1.0000e-04
# Epoch 9/100
# 64/64 [==============================] - 47s 742ms/step - loss: 0.5506 - accuracy: 0.7712 - val_loss: 0.5379 - val_accuracy: 0.7862 - lr: 1.0000e-04
# Epoch 10/100
# 64/64 [==============================] - 49s 758ms/step - loss: 0.4647 - accuracy: 0.8194 - val_loss: 0.4429 - val_accuracy: 0.8414 - lr: 1.0000e-04
# Epoch 11/100
# 64/64 [==============================] - 49s 764ms/step - loss: 0.3751 - accuracy: 0.8637 - val_loss: 0.3945 - val_accuracy: 0.8672 - lr: 1.0000e-04
# Epoch 12/100
# 64/64 [==============================] - 46s 724ms/step - loss: 0.3226 - accuracy: 0.8971 - val_loss: 0.3203 - val_accuracy: 0.8966 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 47s 741ms/step - loss: 0.2907 - accuracy: 0.9060 - val_loss: 0.3074 - val_accuracy: 0.8948 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 51s 799ms/step - loss: 0.2706 - accuracy: 0.9070 - val_loss: 0.2799 - val_accuracy: 0.8983 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 49s 772ms/step - loss: 0.2609 - accuracy: 0.9055 - val_loss: 0.2929 - val_accuracy: 0.8983 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 48s 748ms/step - loss: 0.2492 - accuracy: 0.9085 - val_loss: 0.2756 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 48s 745ms/step - loss: 0.2433 - accuracy: 0.9085 - val_loss: 0.2765 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 47s 729ms/step - loss: 0.2449 - accuracy: 0.9119 - val_loss: 0.2935 - val_accuracy: 0.8983 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 48s 746ms/step - loss: 0.2335 - accuracy: 0.9144 - val_loss: 0.2828 - val_accuracy: 0.8948 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 46s 713ms/step - loss: 0.2263 - accuracy: 0.9139 - val_loss: 0.2890 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 46s 714ms/step - loss: 0.2210 - accuracy: 0.9203 - val_loss: 0.2961 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 46s 716ms/step - loss: 0.2073 - accuracy: 0.9193 - val_loss: 0.2841 - val_accuracy: 0.9000 - lr: 2.0000e-05
# Epoch 23/100
# 64/64 [==============================] - 46s 723ms/step - loss: 0.2045 - accuracy: 0.9173 - val_loss: 0.2898 - val_accuracy: 0.8983 - lr: 2.0000e-05
# Epoch 24/100
# 64/64 [==============================] - 47s 731ms/step - loss: 0.2099 - accuracy: 0.9213 - val_loss: 0.2888 - val_accuracy: 0.9000 - lr: 2.0000e-05
# Epoch 25/100
# 64/64 [==============================] - 47s 727ms/step - loss: 0.2001 - accuracy: 0.9198 - val_loss: 0.2927 - val_accuracy: 0.8983 - lr: 2.0000e-05
# Epoch 26/100
# 64/64 [==============================] - 46s 721ms/step - loss: 0.2025 - accuracy: 0.9149 - val_loss: 0.2927 - val_accuracy: 0.8983 - lr: 2.0000e-05

# %%
test_loss, test_acc = cnn_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 3s 310ms/step - loss: 0.3181 - accuracy: 0.8973
# Test Accuracy: 89.73%

# %% [markdown]
# The CNN model for Kmers=5 has performed exceptionally well on the test set, achieving an accuracy of 89.73%. This high level of accuracy, along with a low test loss, suggests that the model is both effective and reliable.
# The consistency between validation and test performance indicates good generalization, an essential characteristic for deploying the model in practical applications.
# Overall, the results demonstrate that the model has effectively learned to classify the data and can be considered successful for the given task. Further improvements could still be explored to enhance performance and robustness, but the current model already shows a high degree of proficiency.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_cnn.history['accuracy'], label='train_accuracy')
ax1.plot(history_cnn.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history_cnn.history['loss'], label='train_loss')
ax2.plot(history_cnn.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
y_pred = cnn_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 2s 150ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90       146
#            1       0.97      0.82      0.89       146
#
#     accuracy                           0.90       292
#    macro avg       0.91      0.90      0.90       292
# weighted avg       0.91      0.90      0.90       292

# %% [markdown]
# The CNN model for Kmers=5 has achieved a high overall accuracy of 90%, with strong precision, recall, and F1-scores for both classes.
# The model demonstrates balanced performance, effectively handling both classes without significant bias.
# The slight difference in recall between the classes suggests room for minor improvement, particularly in enhancing the recall for class 1.
# Overall, the model's performance is robust and reliable, making it well-suited for the classification task at hand.

# %%
input_shape = (img_height, img_width, 3)
input_layer = Input(shape=input_shape)

cnn_layer = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten()
])
cnn_output = cnn_layer(input_layer)
cnn_output = Dense(128, activation='relu')(cnn_output)
cnn_output = Dropout(0.5)(cnn_output)
cnn_output = Reshape((128, 1))(cnn_output)
rnn_layer = Bidirectional(LSTM(64))(cnn_output)
output_layer = Dense(1, activation='sigmoid')(rnn_layer)

cnn_rnn_model = Model(inputs=input_layer, outputs=output_layer)
cnn_rnn_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
cnn_rnn_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_1 (Sequential)   (None, 86528)             93248
#
#  dense_2 (Dense)             (None, 128)               11075712
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  reshape (Reshape)           (None, 128, 1)            0
#
#  bidirectional (Bidirectiona  (None, 128)              33792
#  l)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 11,202,881
# Trainable params: 11,202,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_cnn_rnn_model.h5', save_best_only=True)
]
history_cnn_rnn = cnn_rnn_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 54s 806ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 50s 773ms/step - loss: 0.6931 - accuracy: 0.5079 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 48s 754ms/step - loss: 0.6935 - accuracy: 0.4857 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 48s 752ms/step - loss: 0.6932 - accuracy: 0.5015 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 49s 761ms/step - loss: 0.6931 - accuracy: 0.4995 - val_loss: 0.6929 - val_accuracy: 0.5793 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 48s 757ms/step - loss: 0.6933 - accuracy: 0.5113 - val_loss: 0.6926 - val_accuracy: 0.5017 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 48s 756ms/step - loss: 0.6925 - accuracy: 0.5271 - val_loss: 0.6923 - val_accuracy: 0.5569 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 49s 758ms/step - loss: 0.6924 - accuracy: 0.5266 - val_loss: 0.6913 - val_accuracy: 0.5638 - lr: 1.0000e-04
# Epoch 9/100
# 64/64 [==============================] - 49s 758ms/step - loss: 0.6894 - accuracy: 0.5531 - val_loss: 0.6867 - val_accuracy: 0.6345 - lr: 1.0000e-04
# Epoch 10/100
# 64/64 [==============================] - 48s 755ms/step - loss: 0.6832 - accuracy: 0.5925 - val_loss: 0.6729 - val_accuracy: 0.6931 - lr: 1.0000e-04
# Epoch 11/100
# 64/64 [==============================] - 48s 757ms/step - loss: 0.5980 - accuracy: 0.7239 - val_loss: 0.4392 - val_accuracy: 0.8121 - lr: 1.0000e-04
# Epoch 12/100
# 64/64 [==============================] - 48s 755ms/step - loss: 0.2991 - accuracy: 0.8878 - val_loss: 0.2713 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 48s 755ms/step - loss: 0.2594 - accuracy: 0.9085 - val_loss: 0.2624 - val_accuracy: 0.9052 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 48s 752ms/step - loss: 0.2561 - accuracy: 0.9090 - val_loss: 0.2647 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 48s 756ms/step - loss: 0.2570 - accuracy: 0.9085 - val_loss: 0.2606 - val_accuracy: 0.9052 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 49s 763ms/step - loss: 0.2535 - accuracy: 0.9099 - val_loss: 0.2583 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 48s 756ms/step - loss: 0.2536 - accuracy: 0.9094 - val_loss: 0.2582 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 48s 756ms/step - loss: 0.2538 - accuracy: 0.9085 - val_loss: 0.2648 - val_accuracy: 0.9052 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 48s 757ms/step - loss: 0.2534 - accuracy: 0.9099 - val_loss: 0.2579 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 48s 757ms/step - loss: 0.2530 - accuracy: 0.9099 - val_loss: 0.2573 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 48s 756ms/step - loss: 0.2527 - accuracy: 0.9099 - val_loss: 0.2556 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 48s 754ms/step - loss: 0.2527 - accuracy: 0.9099 - val_loss: 0.2549 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 23/100
# 64/64 [==============================] - 48s 753ms/step - loss: 0.2522 - accuracy: 0.9099 - val_loss: 0.2668 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 24/100
# 64/64 [==============================] - 48s 751ms/step - loss: 0.2782 - accuracy: 0.8996 - val_loss: 0.2681 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 25/100
# 64/64 [==============================] - 48s 755ms/step - loss: 0.3098 - accuracy: 0.8848 - val_loss: 0.2665 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 26/100
# 64/64 [==============================] - 48s 753ms/step - loss: 0.2563 - accuracy: 0.9090 - val_loss: 0.2637 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 27/100
# 64/64 [==============================] - 48s 756ms/step - loss: 0.2532 - accuracy: 0.9094 - val_loss: 0.2645 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 28/100
# 64/64 [==============================] - 48s 752ms/step - loss: 0.2517 - accuracy: 0.9099 - val_loss: 0.2643 - val_accuracy: 0.9034 - lr: 2.0000e-05
# Epoch 29/100
# 64/64 [==============================] - 48s 751ms/step - loss: 0.2525 - accuracy: 0.9094 - val_loss: 0.2629 - val_accuracy: 0.9034 - lr: 2.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 48s 754ms/step - loss: 0.2515 - accuracy: 0.9099 - val_loss: 0.2621 - val_accuracy: 0.9052 - lr: 2.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 48s 752ms/step - loss: 0.2517 - accuracy: 0.9099 - val_loss: 0.2617 - val_accuracy: 0.9052 - lr: 2.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 48s 752ms/step - loss: 0.2511 - accuracy: 0.9099 - val_loss: 0.2617 - val_accuracy: 0.9052 - lr: 2.0000e-05

# %%
test_loss, test_acc = cnn_rnn_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 3s 250ms/step - loss: 0.2889 - accuracy: 0.9007
# Test Accuracy: 90.07%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_cnn_rnn.history['accuracy'], label='train_accuracy')
ax1.plot(history_cnn_rnn.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history_cnn_rnn.history['loss'], label='train_loss')
ax2.plot(history_cnn_rnn.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
y_pred = cnn_rnn_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 4s 235ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       146
#            1       0.99      0.81      0.89       146
#
#     accuracy                           0.90       292
#    macro avg       0.91      0.90      0.90       292
# weighted avg       0.91      0.90      0.90       292

# %%
vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
for layer in vgg16_base.layers:
    layer.trainable = False

vgg16_model = Sequential([
    vgg16_base,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

vgg16_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
vgg16_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 256)               6422784
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_vgg16_model.h5', save_best_only=True)
]

history_vgg16 = vgg16_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 176s 3s/step - loss: 0.7384 - accuracy: 0.4936 - val_loss: 0.6895 - val_accuracy: 0.5448 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6959 - accuracy: 0.5123 - val_loss: 0.6906 - val_accuracy: 0.5190 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6924 - accuracy: 0.5300 - val_loss: 0.6919 - val_accuracy: 0.5017 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6933 - accuracy: 0.5094 - val_loss: 0.6894 - val_accuracy: 0.5810 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6916 - accuracy: 0.5138 - val_loss: 0.6882 - val_accuracy: 0.5741 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6892 - accuracy: 0.5384 - val_loss: 0.6866 - val_accuracy: 0.5690 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6879 - accuracy: 0.5408 - val_loss: 0.6839 - val_accuracy: 0.5845 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.6836 - accuracy: 0.5581 - val_loss: 0.6830 - val_accuracy: 0.5672 - lr: 1.0000e-04
# Epoch 9/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6860 - accuracy: 0.5433 - val_loss: 0.6831 - val_accuracy: 0.5862 - lr: 1.0000e-04
# Epoch 10/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6809 - accuracy: 0.5664 - val_loss: 0.6810 - val_accuracy: 0.6052 - lr: 1.0000e-04
# Epoch 11/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6854 - accuracy: 0.5522 - val_loss: 0.6800 - val_accuracy: 0.5931 - lr: 1.0000e-04
# Epoch 12/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6839 - accuracy: 0.5566 - val_loss: 0.6819 - val_accuracy: 0.5966 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6819 - accuracy: 0.5635 - val_loss: 0.6807 - val_accuracy: 0.6155 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6834 - accuracy: 0.5522 - val_loss: 0.6789 - val_accuracy: 0.6328 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6789 - accuracy: 0.5659 - val_loss: 0.6774 - val_accuracy: 0.6259 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6751 - accuracy: 0.6004 - val_loss: 0.6768 - val_accuracy: 0.6017 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6778 - accuracy: 0.5822 - val_loss: 0.6753 - val_accuracy: 0.6293 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6714 - accuracy: 0.5881 - val_loss: 0.6735 - val_accuracy: 0.6138 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6734 - accuracy: 0.5906 - val_loss: 0.6722 - val_accuracy: 0.6397 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6701 - accuracy: 0.5969 - val_loss: 0.6728 - val_accuracy: 0.6155 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6706 - accuracy: 0.5994 - val_loss: 0.6681 - val_accuracy: 0.6414 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6628 - accuracy: 0.6334 - val_loss: 0.6727 - val_accuracy: 0.5759 - lr: 1.0000e-04
# Epoch 23/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6674 - accuracy: 0.6014 - val_loss: 0.6647 - val_accuracy: 0.6345 - lr: 1.0000e-04
# Epoch 24/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6603 - accuracy: 0.6142 - val_loss: 0.6607 - val_accuracy: 0.6569 - lr: 1.0000e-04
# Epoch 25/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6614 - accuracy: 0.5999 - val_loss: 0.6631 - val_accuracy: 0.6103 - lr: 1.0000e-04
# Epoch 26/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6525 - accuracy: 0.6368 - val_loss: 0.6579 - val_accuracy: 0.6241 - lr: 1.0000e-04
# Epoch 27/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6521 - accuracy: 0.6324 - val_loss: 0.6603 - val_accuracy: 0.6224 - lr: 1.0000e-04
# Epoch 28/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6529 - accuracy: 0.6250 - val_loss: 0.6558 - val_accuracy: 0.6500 - lr: 1.0000e-04
# Epoch 29/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6446 - accuracy: 0.6462 - val_loss: 0.6515 - val_accuracy: 0.6603 - lr: 1.0000e-04
# Epoch 30/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6443 - accuracy: 0.6471 - val_loss: 0.6532 - val_accuracy: 0.6207 - lr: 1.0000e-04
# Epoch 31/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6461 - accuracy: 0.6516 - val_loss: 0.6472 - val_accuracy: 0.6724 - lr: 1.0000e-04
# Epoch 32/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6356 - accuracy: 0.6526 - val_loss: 0.6465 - val_accuracy: 0.6328 - lr: 1.0000e-04
# Epoch 33/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6374 - accuracy: 0.6599 - val_loss: 0.6470 - val_accuracy: 0.6586 - lr: 1.0000e-04
# Epoch 34/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6350 - accuracy: 0.6585 - val_loss: 0.6526 - val_accuracy: 0.6155 - lr: 1.0000e-04
# Epoch 35/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6353 - accuracy: 0.6555 - val_loss: 0.6510 - val_accuracy: 0.6103 - lr: 1.0000e-04
# Epoch 36/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6219 - accuracy: 0.6836 - val_loss: 0.6403 - val_accuracy: 0.6466 - lr: 1.0000e-04
# Epoch 37/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6312 - accuracy: 0.6698 - val_loss: 0.6369 - val_accuracy: 0.6690 - lr: 1.0000e-04
# Epoch 38/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6214 - accuracy: 0.6944 - val_loss: 0.6320 - val_accuracy: 0.6793 - lr: 1.0000e-04
# Epoch 39/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6193 - accuracy: 0.6836 - val_loss: 0.6313 - val_accuracy: 0.6724 - lr: 1.0000e-04
# Epoch 40/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6182 - accuracy: 0.6929 - val_loss: 0.6310 - val_accuracy: 0.6655 - lr: 1.0000e-04
# Epoch 41/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6087 - accuracy: 0.6959 - val_loss: 0.6261 - val_accuracy: 0.6672 - lr: 1.0000e-04
# Epoch 42/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6189 - accuracy: 0.6752 - val_loss: 0.6230 - val_accuracy: 0.6897 - lr: 1.0000e-04
# Epoch 43/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6057 - accuracy: 0.6870 - val_loss: 0.6241 - val_accuracy: 0.6690 - lr: 1.0000e-04
# Epoch 44/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6037 - accuracy: 0.7131 - val_loss: 0.6162 - val_accuracy: 0.6879 - lr: 1.0000e-04
# Epoch 45/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6005 - accuracy: 0.7032 - val_loss: 0.6199 - val_accuracy: 0.6897 - lr: 1.0000e-04
# Epoch 46/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6031 - accuracy: 0.6998 - val_loss: 0.6145 - val_accuracy: 0.6931 - lr: 1.0000e-04
# Epoch 47/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.5875 - accuracy: 0.7156 - val_loss: 0.6127 - val_accuracy: 0.6948 - lr: 1.0000e-04
# Epoch 48/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5909 - accuracy: 0.7116 - val_loss: 0.6108 - val_accuracy: 0.6862 - lr: 1.0000e-04
# Epoch 49/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5830 - accuracy: 0.7180 - val_loss: 0.6046 - val_accuracy: 0.7069 - lr: 1.0000e-04
# Epoch 50/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5791 - accuracy: 0.7210 - val_loss: 0.6050 - val_accuracy: 0.7052 - lr: 1.0000e-04
# Epoch 51/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5816 - accuracy: 0.7372 - val_loss: 0.5993 - val_accuracy: 0.7034 - lr: 1.0000e-04
# Epoch 52/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5810 - accuracy: 0.7234 - val_loss: 0.6074 - val_accuracy: 0.6828 - lr: 1.0000e-04
# Epoch 53/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5707 - accuracy: 0.7303 - val_loss: 0.5926 - val_accuracy: 0.7052 - lr: 1.0000e-04
# Epoch 54/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5661 - accuracy: 0.7333 - val_loss: 0.5956 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 55/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5623 - accuracy: 0.7411 - val_loss: 0.5896 - val_accuracy: 0.7103 - lr: 1.0000e-04
# Epoch 56/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5587 - accuracy: 0.7446 - val_loss: 0.5862 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 57/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5636 - accuracy: 0.7406 - val_loss: 0.5897 - val_accuracy: 0.7224 - lr: 1.0000e-04
# Epoch 58/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5618 - accuracy: 0.7530 - val_loss: 0.5845 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 59/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5537 - accuracy: 0.7470 - val_loss: 0.5804 - val_accuracy: 0.7293 - lr: 1.0000e-04
# Epoch 60/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5438 - accuracy: 0.7648 - val_loss: 0.5786 - val_accuracy: 0.7155 - lr: 1.0000e-04
# Epoch 61/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5439 - accuracy: 0.7662 - val_loss: 0.5758 - val_accuracy: 0.7293 - lr: 1.0000e-04
# Epoch 62/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5505 - accuracy: 0.7510 - val_loss: 0.5883 - val_accuracy: 0.7034 - lr: 1.0000e-04
# Epoch 63/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5350 - accuracy: 0.7731 - val_loss: 0.5767 - val_accuracy: 0.7310 - lr: 1.0000e-04
# Epoch 64/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5297 - accuracy: 0.7589 - val_loss: 0.5703 - val_accuracy: 0.7293 - lr: 1.0000e-04
# Epoch 65/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5297 - accuracy: 0.7702 - val_loss: 0.5695 - val_accuracy: 0.7276 - lr: 1.0000e-04
# Epoch 66/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.5282 - accuracy: 0.7534 - val_loss: 0.5741 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 67/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5225 - accuracy: 0.7697 - val_loss: 0.5694 - val_accuracy: 0.7190 - lr: 1.0000e-04
# Epoch 68/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5191 - accuracy: 0.7800 - val_loss: 0.5644 - val_accuracy: 0.7328 - lr: 1.0000e-04
# Epoch 69/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5103 - accuracy: 0.7830 - val_loss: 0.5561 - val_accuracy: 0.7397 - lr: 1.0000e-04
# Epoch 70/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5139 - accuracy: 0.7781 - val_loss: 0.5566 - val_accuracy: 0.7431 - lr: 1.0000e-04
# Epoch 71/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5087 - accuracy: 0.7830 - val_loss: 0.5711 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 72/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5008 - accuracy: 0.7928 - val_loss: 0.5497 - val_accuracy: 0.7448 - lr: 1.0000e-04
# Epoch 73/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.5034 - accuracy: 0.7953 - val_loss: 0.5557 - val_accuracy: 0.7466 - lr: 1.0000e-04
# Epoch 74/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.5110 - accuracy: 0.7692 - val_loss: 0.5624 - val_accuracy: 0.7241 - lr: 1.0000e-04
# Epoch 75/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.5003 - accuracy: 0.8007 - val_loss: 0.5479 - val_accuracy: 0.7517 - lr: 1.0000e-04
# Epoch 76/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4814 - accuracy: 0.8031 - val_loss: 0.5460 - val_accuracy: 0.7586 - lr: 1.0000e-04
# Epoch 77/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4851 - accuracy: 0.8017 - val_loss: 0.5448 - val_accuracy: 0.7448 - lr: 1.0000e-04
# Epoch 78/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.4876 - accuracy: 0.7918 - val_loss: 0.5406 - val_accuracy: 0.7569 - lr: 1.0000e-04
# Epoch 79/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.4766 - accuracy: 0.8125 - val_loss: 0.5401 - val_accuracy: 0.7638 - lr: 1.0000e-04
# Epoch 80/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4750 - accuracy: 0.8071 - val_loss: 0.5435 - val_accuracy: 0.7552 - lr: 1.0000e-04
# Epoch 81/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.4791 - accuracy: 0.8036 - val_loss: 0.5479 - val_accuracy: 0.7379 - lr: 1.0000e-04
# Epoch 82/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4724 - accuracy: 0.8031 - val_loss: 0.5398 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 83/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4661 - accuracy: 0.8145 - val_loss: 0.5324 - val_accuracy: 0.7586 - lr: 1.0000e-04
# Epoch 84/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4627 - accuracy: 0.8199 - val_loss: 0.5344 - val_accuracy: 0.7603 - lr: 1.0000e-04
# Epoch 85/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4530 - accuracy: 0.8268 - val_loss: 0.5273 - val_accuracy: 0.7586 - lr: 1.0000e-04
# Epoch 86/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4547 - accuracy: 0.8189 - val_loss: 0.5238 - val_accuracy: 0.7621 - lr: 1.0000e-04
# Epoch 87/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4546 - accuracy: 0.8150 - val_loss: 0.5259 - val_accuracy: 0.7672 - lr: 1.0000e-04
# Epoch 88/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4542 - accuracy: 0.8091 - val_loss: 0.5210 - val_accuracy: 0.7707 - lr: 1.0000e-04
# Epoch 89/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4490 - accuracy: 0.8184 - val_loss: 0.5395 - val_accuracy: 0.7276 - lr: 1.0000e-04
# Epoch 90/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4462 - accuracy: 0.8273 - val_loss: 0.5192 - val_accuracy: 0.7776 - lr: 1.0000e-04
# Epoch 91/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4318 - accuracy: 0.8386 - val_loss: 0.5176 - val_accuracy: 0.7741 - lr: 1.0000e-04
# Epoch 92/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4377 - accuracy: 0.8337 - val_loss: 0.5252 - val_accuracy: 0.7603 - lr: 1.0000e-04
# Epoch 93/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4281 - accuracy: 0.8337 - val_loss: 0.5162 - val_accuracy: 0.7707 - lr: 1.0000e-04
# Epoch 94/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4292 - accuracy: 0.8366 - val_loss: 0.5110 - val_accuracy: 0.7845 - lr: 1.0000e-04
# Epoch 95/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4275 - accuracy: 0.8445 - val_loss: 0.5143 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 96/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4291 - accuracy: 0.8376 - val_loss: 0.5116 - val_accuracy: 0.7672 - lr: 1.0000e-04
# Epoch 97/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4157 - accuracy: 0.8504 - val_loss: 0.5093 - val_accuracy: 0.7862 - lr: 1.0000e-04
# Epoch 98/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4183 - accuracy: 0.8420 - val_loss: 0.5109 - val_accuracy: 0.7810 - lr: 1.0000e-04
# Epoch 99/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4196 - accuracy: 0.8425 - val_loss: 0.5066 - val_accuracy: 0.7897 - lr: 1.0000e-04
# Epoch 100/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.4149 - accuracy: 0.8391 - val_loss: 0.5252 - val_accuracy: 0.7500 - lr: 1.0000e-04

# %%
test_loss, test_acc = vgg16_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 20s 2s/step - loss: 0.5386 - accuracy: 0.7226
# Test Accuracy: 72.26%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_vgg16.history['accuracy'], label='train_accuracy')
ax1.plot(history_vgg16.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax2.plot(history_vgg16.history['loss'], label='train_loss')
ax2.plot(history_vgg16.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
plt.show()

# %%
y_pred = vgg16_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 20s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.66      0.93      0.77       146
#            1       0.88      0.51      0.65       146
#
#     accuracy                           0.72       292
#    macro avg       0.77      0.72      0.71       292
# weighted avg       0.77      0.72      0.71       292

# %%
resnet50_base = ResNet50(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in resnet50_base.layers:
    layer.trainable = False

resnet50_model = Sequential([
    resnet50_base,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

resnet50_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
resnet50_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_3 (Flatten)         (None, 100352)            0
#
#  dense_6 (Dense)             (None, 256)               25690368
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 49,278,337
# Trainable params: 25,690,625
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_resnet50_model.h5', save_best_only=True)
]

history_resnet50 = resnet50_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 176s 3s/step - loss: 0.8782 - accuracy: 0.5167 - val_loss: 0.6937 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6987 - accuracy: 0.4857 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6939 - accuracy: 0.4902 - val_loss: 0.6932 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6933 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.5084 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6935 - accuracy: 0.5123 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 2.0000e-05
# Epoch 9/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6931 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 2.0000e-05
# Epoch 10/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6931 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 2.0000e-05
# Epoch 11/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 2.0000e-05
# Epoch 12/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 2.0000e-05
# Epoch 13/100
# 64/64 [==============================] - 166s 3s/step - loss: 0.6931 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 4.0000e-06
# Epoch 14/100
# 64/64 [==============================] - 100s 2s/step - loss: 0.6931 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 4.0000e-06
# Epoch 15/100
# 64/64 [==============================] - 101s 2s/step - loss: 0.6931 - accuracy: 0.5020 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 4.0000e-06
# Epoch 16/100
# 64/64 [==============================] - 101s 2s/step - loss: 0.6931 - accuracy: 0.5015 - val_loss: 0.6932 - val_accuracy: 0.4983 - lr: 4.0000e-06

# %%
test_loss, test_acc = resnet50_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 18s 2s/step - loss: 0.6929 - accuracy: 0.5000
# Test Accuracy: 50.00%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_resnet50.history['accuracy'], label='train_accuracy')
ax1.plot(history_resnet50.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history_resnet50.history['loss'], label='train_loss')
ax2.plot(history_resnet50.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
y_pred = resnet50_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 19s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       146
#            1       0.50      1.00      0.67       146
#
#     accuracy                           0.50       292
#    macro avg       0.25      0.50      0.33       292
# weighted avg       0.25      0.50      0.33       292
# C:\Users\Badis\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Badis\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Badis\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
