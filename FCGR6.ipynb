# %% [markdown]
# For the first step we will import every function needed in our code , we will work basically with Tensorflow Library where we will use it for a simple CNN , then for an Hybrid Model (CNN+RNN) , then for a pre-trained vgg16 model and finally for a ResNet50 pre-trained Model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, LSTM, Conv1D, Reshape, MaxPooling1D, TimeDistributed, Bidirectional
from keras.layers import Input
from keras.applications import VGG16, ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
img_height, img_width = 224, 224
batch_size = 32
data_dir = 'FCGR_Analysiss_k6'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'),
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(data_dir, 'validation'),
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(data_dir, 'test'),
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 2032 images belonging to 2 classes.
# Found 580 images belonging to 2 classes.
# Found 292 images belonging to 2 classes.

# %%
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

cnn_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 11,169,089
# Trainable params: 11,169,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_cnn_model.h5', save_best_only=True)
]

history_cnn = cnn_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 52s 802ms/step - loss: 0.6998 - accuracy: 0.4921 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 46s 723ms/step - loss: 0.6933 - accuracy: 0.5162 - val_loss: 0.6920 - val_accuracy: 0.5086 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 46s 714ms/step - loss: 0.6928 - accuracy: 0.5241 - val_loss: 0.6909 - val_accuracy: 0.5362 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 46s 715ms/step - loss: 0.6911 - accuracy: 0.5157 - val_loss: 0.6888 - val_accuracy: 0.5603 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 46s 714ms/step - loss: 0.6905 - accuracy: 0.5231 - val_loss: 0.6897 - val_accuracy: 0.5155 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 46s 721ms/step - loss: 0.6904 - accuracy: 0.5217 - val_loss: 0.6876 - val_accuracy: 0.5431 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 46s 720ms/step - loss: 0.6858 - accuracy: 0.5379 - val_loss: 0.6838 - val_accuracy: 0.5466 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 46s 719ms/step - loss: 0.6854 - accuracy: 0.5531 - val_loss: 0.6824 - val_accuracy: 0.5879 - lr: 1.0000e-04
# Epoch 9/100
# 64/64 [==============================] - 46s 716ms/step - loss: 0.6792 - accuracy: 0.5896 - val_loss: 0.6790 - val_accuracy: 0.5431 - lr: 1.0000e-04
# Epoch 10/100
# 64/64 [==============================] - 46s 716ms/step - loss: 0.6730 - accuracy: 0.5915 - val_loss: 0.6788 - val_accuracy: 0.5276 - lr: 1.0000e-04
# Epoch 11/100
# 64/64 [==============================] - 46s 718ms/step - loss: 0.6611 - accuracy: 0.6329 - val_loss: 0.6629 - val_accuracy: 0.6448 - lr: 1.0000e-04
# Epoch 29/100
# 64/64 [==============================] - 46s 715ms/step - loss: 0.1646 - accuracy: 0.9321 - val_loss: 0.2647 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 46s 721ms/step - loss: 0.1602 - accuracy: 0.9321 - val_loss: 0.2701 - val_accuracy: 0.9121 - lr: 2.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 46s 715ms/step - loss: 0.1521 - accuracy: 0.9375 - val_loss: 0.2744 - val_accuracy: 0.9069 - lr: 2.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 46s 716ms/step - loss: 0.1496 - accuracy: 0.9365 - val_loss: 0.2807 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 33/100
# 64/64 [==============================] - 46s 718ms/step - loss: 0.1498 - accuracy: 0.9365 - val_loss: 0.2789 - val_accuracy: 0.9052 - lr: 2.0000e-05

# %%
test_loss, test_acc = cnn_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 3s 320ms/step - loss: 0.2346 - accuracy: 0.9247
# Test Accuracy: 92.47%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_cnn.history['accuracy'], label='train_accuracy')
ax1.plot(history_cnn.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history_cnn.history['loss'], label='train_loss')
ax2.plot(history_cnn.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
y_pred = cnn_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 2s 143ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       146
#            1       1.00      0.85      0.92       146
#
#     accuracy                           0.92       292
#    macro avg       0.93      0.92      0.92       292
# weighted avg       0.93      0.92      0.92       292

# %%
input_shape = (img_height, img_width, 3)
input_layer = Input(shape=input_shape)

cnn_layer = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten()
])
cnn_output = cnn_layer(input_layer)
cnn_output = Dense(128, activation='relu')(cnn_output)
cnn_output = Dropout(0.5)(cnn_output)
cnn_output = Reshape((128, 1))(cnn_output)
rnn_layer = Bidirectional(LSTM(64))(cnn_output)
output_layer = Dense(1, activation='sigmoid')(rnn_layer)

cnn_rnn_model = Model(inputs=input_layer, outputs=output_layer)
cnn_rnn_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
cnn_rnn_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_1 (Sequential)   (None, 86528)             93248
#
#  dense_2 (Dense)             (None, 128)               11075712
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  reshape (Reshape)           (None, 128, 1)            0
#
#  bidirectional (Bidirectiona  (None, 128)              33792
#  l)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 11,202,881
# Trainable params: 11,202,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_cnn_rnn_model.h5', save_best_only=True)
]
history_cnn_rnn = cnn_rnn_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 56s 831ms/step - loss: 0.6933 - accuracy: 0.4990 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch
# 64/64 [==============================] - 48s 755ms/step - loss: 0.1164 - accuracy: 0.9670 - val_loss: 0.4739 - val_accuracy: 0.8293 - lr: 1.0000e-06
# Epoch 89/100
# 64/64 [==============================] - 49s 764ms/step - loss: 0.1216 - accuracy: 0.9611 - val_loss: 0.4707 - val_accuracy: 0.8276 - lr: 1.0000e-06

# %%
test_loss, test_acc = cnn_rnn_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 2s 156ms/step - loss: 0.3847 - accuracy: 0.8527
# Test Accuracy: 85.27%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_cnn_rnn.history['accuracy'], label='train_accuracy')
ax1.plot(history_cnn_rnn.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history_cnn_rnn.history['loss'], label='train_loss')
ax2.plot(history_cnn_rnn.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
y_pred = cnn_rnn_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 2s 156ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86       146
#            1       0.91      0.78      0.84       146
#
#     accuracy                           0.85       292
#    macro avg       0.86      0.85      0.85       292
# weighted avg       0.86      0.85      0.85       292

# %%
vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
for layer in vgg16_base.layers:
    layer.trainable = False

vgg16_model = Sequential([
    vgg16_base,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

vgg16_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
vgg16_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 256)               6422784
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_vgg16_model.h5', save_best_only=True)
]

history_vgg16 = vgg16_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.7297 - accuracy: 0.5148 - val_loss: 0.6894 - val_accuracy: 0.5241 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.7005 - accuracy: 0.5123 - val_loss: 0.6890 - val_accuracy: 0.5431 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6970 - accuracy: 0.5148 - val_loss: 0.6898 - val_accuracy: 0.5759 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6931 - accuracy: 0.5276 - val_loss: 0.6960 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.6941 - accuracy: 0.4985 - val_loss: 0.6910 - val_accuracy: 0.5086 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6918 - accuracy: 0.5246 - val_loss: 0.6908 - val_accuracy: 0.5259 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6912 - accuracy: 0.5340 - val_loss: 0.6933 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6922 - accuracy: 0.5177 - val_loss: 0.6907 - val_accuracy: 0.5362 - lr: 2.0000e-05
# Epoch 9/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6907 - accuracy: 0.5256 - val_loss: 0.6901 - val_accuracy: 0.5603 - lr: 2.0000e-05
# Epoch 10/100
# 64/64 [==============================] - 172s 3s/step - loss: 0.6898 - accuracy: 0.5399 - val_loss: 0.6894 - val_accuracy: 0.5586 - lr: 2.0000e-05
# Epoch 11/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.6878 - accuracy: 0.5497 - val_loss: 0.6893 - val_accuracy: 0.5466 - lr: 2.0000e-05
# Epoch 12/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.6896 - accuracy: 0.5266 - val_loss: 0.6888 - val_accuracy: 0.5707 - lr: 2.0000e-05
# Epoch 13/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.6892 - accuracy: 0.5463 - val_loss: 0.6887 - val_accuracy: 0.5741 - lr: 2.0000e-05
# Epoch 14/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6890 - accuracy: 0.5418 - val_loss: 0.6886 - val_accuracy: 0.5793 - lr: 2.0000e-05
# Epoch 15/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6879 - accuracy: 0.5600 - val_loss: 0.6884 - val_accuracy: 0.5655 - lr: 2.0000e-05
# Epoch 16/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6878 - accuracy: 0.5551 - val_loss: 0.6884 - val_accuracy: 0.5741 - lr: 2.0000e-05
# Epoch 17/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6886 - accuracy: 0.5561 - val_loss: 0.6884 - val_accuracy: 0.5655 - lr: 2.0000e-05
# Epoch 18/100
# 64/64 [==============================] - 170s 3s/step - loss: 0.6875 - accuracy: 0.5566 - val_loss: 0.6882 - val_accuracy: 0.5793 - lr: 2.0000e-05
# Epoch 19/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6869 - accuracy: 0.5615 - val_loss: 0.6877 - val_accuracy: 0.5724 - lr: 2.0000e-05
# Epoch 20/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6878 - accuracy: 0.5620 - val_loss: 0.6879 - val_accuracy: 0.5483 - lr: 2.0000e-05
# Epoch 21/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6883 - accuracy: 0.5433 - val_loss: 0.6874 - val_accuracy: 0.5707 - lr: 2.0000e-05
# Epoch 22/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6878 - accuracy: 0.5527 - val_loss: 0.6876 - val_accuracy: 0.5500 - lr: 2.0000e-05
# Epoch 23/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6860 - accuracy: 0.5689 - val_loss: 0.6869 - val_accuracy: 0.5828 - lr: 2.0000e-05
# Epoch 24/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6872 - accuracy: 0.5522 - val_loss: 0.6869 - val_accuracy: 0.5655 - lr: 2.0000e-05
# Epoch 25/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6855 - accuracy: 0.5610 - val_loss: 0.6865 - val_accuracy: 0.5914 - lr: 2.0000e-05
# Epoch 26/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6855 - accuracy: 0.5738 - val_loss: 0.6862 - val_accuracy: 0.5810 - lr: 2.0000e-05
# Epoch 27/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6849 - accuracy: 0.5576 - val_loss: 0.6863 - val_accuracy: 0.5776 - lr: 2.0000e-05
# Epoch 28/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6872 - accuracy: 0.5566 - val_loss: 0.6859 - val_accuracy: 0.5862 - lr: 2.0000e-05
# Epoch 29/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6852 - accuracy: 0.5625 - val_loss: 0.6859 - val_accuracy: 0.5741 - lr: 2.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6845 - accuracy: 0.5773 - val_loss: 0.6861 - val_accuracy: 0.5724 - lr: 2.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6852 - accuracy: 0.5615 - val_loss: 0.6856 - val_accuracy: 0.5655 - lr: 2.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.
100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6802 - accuracy: 0.5689 - val_loss: 0.6809 - val_accuracy: 0.5897 - lr: 2.0000e-05
# Epoch 58/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6804 - accuracy: 0.5758 - val_loss: 0.6811 - val_accuracy: 0.5914 - lr: 2.0000e-05
# Epoch 59/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6780 - accuracy: 0.5950 - val_loss: 0.6806 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 60/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6796 - accuracy: 0.5851 - val_loss: 0.6802 - val_accuracy: 0.5810 - lr: 2.0000e-05
# Epoch 61/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6765 - accuracy: 0.5984 - val_loss: 0.6801 - val_accuracy: 0.5828 - lr: 2.0000e-05
# Epoch 62/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6761 - accuracy: 0.5871 - val_loss: 0.6797 - val_accuracy: 0.5914 - lr: 2.0000e-05
# Epoch 63/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6777 - accuracy: 0.5871 - val_loss: 0.6797 - val_accuracy: 0.5862 - lr: 2.0000e-05
# Epoch 64/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6776 - accuracy: 0.5881 - val_loss: 0.6801 - val_accuracy: 0.5879 - lr: 2.0000e-05
# Epoch 65/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6776 - accuracy: 0.5906 - val_loss: 0.6794 - val_accuracy: 0.5810 - lr: 2.0000e-05
# Epoch 66/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6757 - accuracy: 0.5984 - val_loss: 0.6791 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 67/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6759 - accuracy: 0.5920 - val_loss: 0.6788 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 68/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6750 - accuracy: 0.6024 - val_loss: 0.6785 - val_accuracy: 0.5931 - lr: 2.0000e-05
# Epoch 69/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6739 - accuracy: 0.6171 - val_loss: 0.6786 - val_accuracy: 0.5931 - lr: 2.0000e-05
# Epoch 70/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6755 - accuracy: 0.5979 - val_loss: 0.6782 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 71/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6737 - accuracy: 0.5960 - val_loss: 0.6782 - val_accuracy: 0.5983 - lr: 2.0000e-05
# Epoch 72/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6742 - accuracy: 0.6083 - val_loss: 0.6778 - val_accuracy: 0.6017 - lr: 2.0000e-05
# Epoch 73/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6745 - accuracy: 0.5827 - val_loss: 0.6780 - val_accuracy: 0.5897 - lr: 2.0000e-05
# Epoch 74/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6735 - accuracy: 0.5965 - val_loss: 0.6775 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 75/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6737 - accuracy: 0.5960 - val_loss: 0.6769 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 76/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6765 - accuracy: 0.5935 - val_loss: 0.6774 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 77/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6736 - accuracy: 0.5950 - val_loss: 0.6768 - val_accuracy: 0.6052 - lr: 2.0000e-05
# Epoch 78/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6737 - accuracy: 0.6171 - val_loss: 0.6766 - val_accuracy: 0.5983 - lr: 2.0000e-05
# Epoch 79/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6718 - accuracy: 0.6038 - val_loss: 0.6761 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 80/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6735 - accuracy: 0.5969 - val_loss: 0.6761 - val_accuracy: 0.5931 - lr: 2.0000e-05
# Epoch 81/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6712 - accuracy: 0.6083 - val_loss: 0.6758 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 82/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6722 - accuracy: 0.5984 - val_loss: 0.6763 - val_accuracy: 0.5862 - lr: 2.0000e-05
# Epoch 83/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6716 - accuracy: 0.6048 - val_loss: 0.6756 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 84/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6720 - accuracy: 0.6068 - val_loss: 0.6757 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 85/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6724 - accuracy: 0.6083 - val_loss: 0.6749 - val_accuracy: 0.5983 - lr: 2.0000e-05
# Epoch 86/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6689 - accuracy: 0.6176 - val_loss: 0.6750 - val_accuracy: 0.5948 - lr: 2.0000e-05
# Epoch 87/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6687 - accuracy: 0.6043 - val_loss: 0.6749 - val_accuracy: 0.5983 - lr: 2.0000e-05
# Epoch 88/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6704 - accuracy: 0.6142 - val_loss: 0.6745 - val_accuracy: 0.6017 - lr: 2.0000e-05
# Epoch 89/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6697 - accuracy: 0.6161 - val_loss: 0.6743 - val_accuracy: 0.6017 - lr: 2.0000e-05
# Epoch 90/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6709 - accuracy: 0.6068 - val_loss: 0.6757 - val_accuracy: 0.5879 - lr: 2.0000e-05
# Epoch 91/100
# 64/64 [==============================] - 167s 3s/step - loss: 0.6696 - accuracy: 0.6078 - val_loss: 0.6743 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 92/100
# 64/64 [==============================] - 167s 3s/step - loss: 0.6684 - accuracy: 0.5979 - val_loss: 0.6737 - val_accuracy: 0.6017 - lr: 2.0000e-05
# Epoch 93/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6686 - accuracy: 0.6117 - val_loss: 0.6736 - val_accuracy: 0.5983 - lr: 2.0000e-05
# Epoch 94/100
# 64/64 [==============================] - 167s 3s/step - loss: 0.6714 - accuracy: 0.5984 - val_loss: 0.6738 - val_accuracy: 0.6103 - lr: 2.0000e-05
# Epoch 95/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6684 - accuracy: 0.6147 - val_loss: 0.6735 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 96/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6678 - accuracy: 0.6083 - val_loss: 0.6728 - val_accuracy: 0.6086 - lr: 2.0000e-05
# Epoch 97/100
# 64/64 [==============================] - 167s 3s/step - loss: 0.6650 - accuracy: 0.6216 - val_loss: 0.6729 - val_accuracy: 0.5914 - lr: 2.0000e-05
# Epoch 98/100
# 64/64 [==============================] - 167s 3s/step - loss: 0.6673 - accuracy: 0.6156 - val_loss: 0.6729 - val_accuracy: 0.5966 - lr: 2.0000e-05
# Epoch 99/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6671 - accuracy: 0.6152 - val_loss: 0.6723 - val_accuracy: 0.6017 - lr: 2.0000e-05
# Epoch 100/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6680 - accuracy: 0.6265 - val_loss: 0.6721 - val_accuracy: 0.6017 - lr: 2.0000e-05

# %%
test_loss, test_acc = vgg16_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 20s 2s/step - loss: 0.6731 - accuracy: 0.6233
# Test Accuracy: 62.33%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_vgg16.history['accuracy'], label='train_accuracy')
ax1.plot(history_vgg16.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax2.plot(history_vgg16.history['loss'], label='train_loss')
ax2.plot(history_vgg16.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
plt.show()

# %%
y_pred = vgg16_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 22s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.64      0.55      0.60       146
#            1       0.61      0.69      0.65       146
#
#     accuracy                           0.62       292
#    macro avg       0.63      0.62      0.62       292
# weighted avg       0.63      0.62      0.62       292

# %%
resnet50_base = ResNet50(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in resnet50_base.layers:
    layer.trainable = False

resnet50_model = Sequential([
    resnet50_base,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

resnet50_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
resnet50_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_3 (Flatten)         (None, 100352)            0
#
#  dense_6 (Dense)             (None, 256)               25690368
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 49,278,337
# Trainable params: 25,690,625
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.2, min_lr=1e-6),
    ModelCheckpoint('best_resnet50_model.h5', save_best_only=True)
]

history_resnet50 = resnet50_model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.9339 - accuracy: 0.4990 - val_loss: 0.6940 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - 171s 3s/step - loss: 0.6962 - accuracy: 0.4970 - val_loss: 0.6938 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6943 - accuracy: 0.4823 - val_loss: 0.6931 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6950 - accuracy: 0.4862 - val_loss: 0.6931 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.4921 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.4980 - val_loss: 0.6931 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6932 - accuracy: 0.4774 - val_loss: 0.6931 - val_accuracy: 0.4983 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6932 - accuracy: 0.4902 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 9/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.0000e-05
# Epoch 10/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.0000e-05
# Epoch 11/100
# 64/64 [==============================] - 168s 3s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.0000e-05
# Epoch 12/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.0000e-05
# Epoch 13/100
# 64/64 [==============================] - 169s 3s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.0000e-05

# %%
test_loss, test_acc = resnet50_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 10/10 [==============================] - 21s 2s/step - loss: 0.6931 - accuracy: 0.5000
# Test Accuracy: 50.00%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.plot(history_resnet50.history['accuracy'], label='train_accuracy')
ax1.plot(history_resnet50.history['val_accuracy'], label='val_accuracy')
ax1.set_title('Model accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history_resnet50.history['loss'], label='train_loss')
ax2.plot(history_resnet50.history['val_loss'], label='val_loss')
ax2.set_title('Model loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
y_pred = resnet50_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)
print(classification_report(test_generator.classes, y_pred))
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 10/10 [==============================] - 21s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       146
#            1       0.50      1.00      0.67       146
#
#     accuracy                           0.50       292
#    macro avg       0.25      0.50      0.33       292
# weighted avg       0.25      0.50      0.33       292
# C:\Users\Badis\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Badis\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Badis\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
